# %%
import zipfile
import os
import pandas as pd

def unzip_and_combine(zip_dir, file_name, format):
    zip_list = os.listdir(f"./{zip_dir}")

# %%
data_loc = "/home/seho/data"
zip_data_loc = "/home/seho/data/zip/마이비 카드 이력 정보"
unzip_data_loc = "/home/seho/data/unzip/마이비 카드 이력 정보"

# %%
if os.path.exists(zip_data_loc) == False:
    os.makedirs(zip_data_loc)
    
if os.path.exists(unzip_data_loc) == False:
    os.makedirs(unzip_data_loc)

# %%
import zipfile
import os
import pandas as pd

# %%
zip_list = os.listdir(zip_data_loc)

# %%
! rm ./MYBI/*.csv

# %%
for i, z_file in enumerate(zip_list):
    # zip이 아닌 파일은 Pass
    if os.path.splitext(z_file)[1] != ".zip":
        continue
    print(f"{i}. Extracting {z_file} ...")
    
    with zipfile.ZipFile(f"{zip_data_loc}/{z_file}", 'r') as zip_ref:
        # file size가 0인 경우는 Pass 한다
        file_size = [x for x in zip_ref.filelist if x.filename == "MYBICARDHISTORY.csv"][0].file_size
        if file_size == 0:
            print("File size 0")
            continue
        
        temp = zip_ref.open("MYBICARDHISTORY.csv")
        print("Find MYBICARDHISTORY.csv")
        pd_temp = pd.read_csv(temp, dtype = {"ROUTE_NM" : str})
        pd_temp.columns = [x.lower() for x in pd_temp.columns]
        
        if "Unnamed: 0" in pd_temp.columns:
            pd_temp = pd_temp.drop("Unnamed: 0", axis = 1)
        
        # 컬럼명(header)만 있고 파일이 없는 경우는 Pass
        if pd_temp.shape[0] == 0:
            continue
        min_date = str(pd_temp["collectdate"].min())[2:]
        max_date = str(pd_temp["collectdate"].max())[2:]

        pd_temp.to_csv(f"{unzip_data_loc}/mybicard_{min_date}_{max_date}.csv", index = False)
        print(f"mybicard_{min_date}_{max_date}.csv")
        del pd_temp
        del temp
# Out:
# 0. Extracting 29_BIS_MYBI - 2021-02-09T174836.150.zip ...
# Find MYBICARDHISTORY.csv
# mybicard_200627_200701.csv
# 1. Extracting 29_BIS_MYBI (20).zip ...
# Find MYBICARDHISTORY.csv
# mybicard_200928_201004.csv
# 2. Extracting 29_BIS_MYBI (88).zip ...
# Find MYBICARDHISTORY.csv
# mybicard_200723_200727.csv
# 3. Extracting 29_BIS_MYBI - 2021-02-09T175043.707.zip ...
# Find MYBICARDHISTORY.csv
# mybicard_200503_200507.csv
# 4. Extracting 29_BIS_MYBI - 2021-02-09T174926.874.zip ...
# Find MYBICARDHISTORY.csv
# mybicard_200609_200613.csv
# 5. Extracting 29_BIS_MYBI (82).zip ...
# Find MYBICARDHISTORY.csv
# mybicard_200729_200803.csv
# 6. Extracting 29_BIS_MYBI - 2021-02-09T175012.733.zip ...
# Find MYBICARDHISTORY.csv
# mybicard_200527_200531.csv
# 7. Extracting 29_BIS_MYBI - 2021-02-09T174920.708.zip ...
# Find MYBICARDHISTORY.csv
# mybicard_200615_200621.csv
# 8. Extracting 29_BIS_MYBI (85).zip ...
# Find MYBICARDHISTORY.csv
# mybicard_200726_200729.csv
# 9. Extracting 29_BIS_MYBI - 2021-02-09T175105.121.zip ...
# Find MYBICARDHISTORY.csv
# mybicard_200410_200414.csv
# 10. Extracting 29_BIS_MYBI - 2021-02-09T175016.879.zip ...
# Find MYBICARDHISTORY.csv
# mybicard_200523_200526.csv
# 11. Extracting 29_BIS_MYBI - 2021-02-09T175030.514.zip ...
# Find MYBICARDHISTORY.csv
# mybicard_200511_200513.csv
# 12. Extracting 29_BIS_MYBI - 2021-02-09T174950.277.zip ...
# Find MYBICARDHISTORY.csv
# mybicard_200604_200608.csv
# 13. Extracting 29_BIS_MYBI - 2021-02-09T175056.740.zip ...
# Find MYBICARDHISTORY.csv
# mybicard_200424_200428.csv
# 14. Extracting 29_BIS_MYBI (14).zip ...
# Find MYBICARDHISTORY.csv
# mybicard_201008_201012.csv
# 15. Extracting 29_BIS_MYBI - 2021-02-09T175027.411.zip ...
# Find MYBICARDHISTORY.csv
# mybicard_200515_200518.csv
# 16. Extracting 29_BIS_MYBI - 2021-02-09T174856.346.zip ...
# Find MYBICARDHISTORY.csv
# mybicard_200623_200628.csv
# 17. Extracting 29_BIS_MYBI (52).zip ...
# Find MYBICARDHISTORY.csv
# mybicard_200829_200901.csv
# 18. Extracting 29_BIS_MYBI - 2021-02-09T174921.896.zip ...
# Find MYBICARDHISTORY.csv
# mybicard_200614_200617.csv
# 19. Extracting TR051900200001 (9).zip ...
# Find MYBICARDHISTORY.csv
# mybicard_201120_201123.csv
# 20. Extracting 29_BIS_MYBI (92).zip ...
# Find MYBICARDHISTORY.csv
# mybicard_200719_200723.csv
# 21. Extracting 29_BIS_MYBI - 2021-02-09T174811.517.zip ...
# Find MYBICARDHISTORY.csv
# mybicard_200708_200713.csv
# 22. Extracting 29_BIS_MYBI (61).zip ...
# Find MYBICARDHISTORY.csv
# mybicard_200820_200824.csv
# 23. Extracting TR051900200001 (6).zip ...
# Find MYBICARDHISTORY.csv
# mybicard_201123_201127.csv
# 24. Extracting 29_BIS_MYBI - 2021-02-09T174812.602.zip ...
# Find MYBICARDHISTORY.csv
# mybicard_200707_200710.csv
# 25. Extracting TR051900200001 (7).zip ...
# Find MYBICARDHISTORY.csv
# mybicard_201122_201125.csv
# 26. Extracting 29_BIS_MYBI (18).zip ...
# Find MYBICARDHISTORY.csv
# mybicard_201001_201005.csv
# 27. Extracting 29_BIS_MYBI (45).zip ...
# Find MYBICARDHISTORY.csv
# mybicard_200907_200910.csv
# 28. Extracting 29_BIS_MYBI (9).zip ...
# Find MYBICARDHISTORY.csv
# mybicard_201013_201016.csv
# 29. Extracting 29_BIS_MYBI.zip ...
# Find MYBICARDHISTORY.csv
# mybicard_201107_201111.csv
# 30. Extracting 29_BIS_MYBI (84).zip ...
# Find MYBICARDHISTORY.csv
# mybicard_200727_200731.csv
# 31. Extracting 29_BIS_MYBI (5).zip ...
# Find MYBICARDHISTORY.csv
# mybicard_201102_201105.csv
# 32. Extracting 29_BIS_MYBI - 2021-02-09T174837.276.zip ...
# Find MYBICARDHISTORY.csv
# mybicard_200626_200701.csv
# 33. Extracting 29_BIS_MYBI (6).zip ...
# Find MYBICARDHISTORY.csv
# mybicard_201101_201104.csv
# 34. Extracting 29_BIS_MYBI (49).zip ...
# Find MYBICARDHISTORY.csv
# mybicard_200903_200909.csv
# 35. Extracting 29_BIS_MYBI (60).zip ...
# Find MYBICARDHISTORY.csv
# 36. Extracting TR051900200001.zip ...
# Find MYBICARDHISTORY.csv
# mybicard_201129_201202.csv
# 37. Extracting 29_BIS_MYBI (59).zip ...
# Find MYBICARDHISTORY.csv
# mybicard_200822_200826.csv
# 38. Extracting 29_BIS_MYBI - 2021-02-09T174827.902.zip ...
# Find MYBICARDHISTORY.csv
# mybicard_200705_200710.csv
# 39. Extracting 29_BIS_MYBI - 2021-02-09T175015.859.zip ...
# Find MYBICARDHISTORY.csv
# mybicard_200524_200527.csv
# 40. Extracting 29_BIS_MYBI - 2021-02-09T175028.486.zip ...
# Find MYBICARDHISTORY.csv
# mybicard_200514_200518.csv
# 41. Extracting 29_BIS_MYBI - 2021-02-09T175046.814.zip ...
# Find MYBICARDHISTORY.csv
# mybicard_200430_200504.csv
# 42. Extracting 29_BIS_MYBI (28).zip ...
# Find MYBICARDHISTORY.csv
# mybicard_200921_200925.csv
# 43. Extracting 29_BIS_MYBI (64).zip ...
# Find MYBICARDHISTORY.csv
# 44. Extracting 29_BIS_MYBI (35).zip ...
# Find MYBICARDHISTORY.csv
# mybicard_200917_200921.csv
# 45. Extracting 29_BIS_MYBI (26).zip ...
# Find MYBICARDHISTORY.csv
# mybicard_200919_200923.csv
# 46. Extracting 29_BIS_MYBI - 2021-02-09T175032.578.zip ...
# Find MYBICARDHISTORY.csv
# mybicard_200509_200512.csv
# 47. Extracting 29_BIS_MYBI (31).zip ...
# Find MYBICARDHISTORY.csv
# mybicard_200926_201001.csv
# 48. Extracting 29_BIS_MYBI - 2021-02-09T174813.543.zip ...
# Find MYBICARDHISTORY.csv
# mybicard_200706_200710.csv
# 49. Extracting 29_BIS_MYBI (34).zip ...
# Find MYBICARDHISTORY.csv
# mybicard_200922_200925.csv
# 50. Extracting 29_BIS_MYBI (77).zip ...
# Find MYBICARDHISTORY.csv
# mybicard_200811_200817.csv
# 51. Extracting 29_BIS_MYBI (23).zip ...
# Find MYBICARDHISTORY.csv
# mybicard_200927_201002.csv
# 52. Extracting 29_BIS_MYBI (65).zip ...
# Find MYBICARDHISTORY.csv
# mybicard_200816_200819.csv
# 53. Extracting 29_BIS_MYBI - 2021-02-09T174829.946.zip ...
# Find MYBICARDHISTORY.csv
# mybicard_200703_200707.csv
# 54. Extracting 29_BIS_MYBI (12).zip ...
# Find MYBICARDHISTORY.csv
# mybicard_201010_201013.csv
# 55. Extracting 29_BIS_MYBI - 2021-02-09T175042.656.zip ...
# Find MYBICARDHISTORY.csv
# mybicard_200505_200509.csv
# 56. Extracting 29_BIS_MYBI - 2021-02-09T174954.423.zip ...
# Find MYBICARDHISTORY.csv
# mybicard_200531_200605.csv
# 57. Extracting 29_BIS_MYBI (95).zip ...
# Find MYBICARDHISTORY.csv
# mybicard_200716_200720.csv
# 58. Extracting 29_BIS_MYBI (27).zip ...
# Find MYBICARDHISTORY.csv
# mybicard_201005_201009.csv
# 59. Extracting 29_BIS_MYBI (15).zip ...
# Find MYBICARDHISTORY.csv
# mybicard_201007_201011.csv
# 60. Extracting 29_BIS_MYBI (74).zip ...
# Find MYBICARDHISTORY.csv
# mybicard_200807_200811.csv
# 61. Extracting 29_BIS_MYBI (79).zip ...
# Find MYBICARDHISTORY.csv
# mybicard_200801_200804.csv
# 62. Extracting 29_BIS_MYBI (7).zip ...
# Find MYBICARDHISTORY.csv
# mybicard_201030_201102.csv
# 63. Extracting 29_BIS_MYBI (73).zip ...
# Find MYBICARDHISTORY.csv
# mybicard_200805_200809.csv
# 64. Extracting 29_BIS_MYBI - 2021-02-09T175041.585.zip ...
# Find MYBICARDHISTORY.csv
# mybicard_200507_200511.csv
# 65. Extracting 29_BIS_MYBI - 2021-02-09T174809.412.zip ...
# Find MYBICARDHISTORY.csv
# mybicard_200710_200715.csv
# 66. Extracting 29_BIS_MYBI (90).zip ...
# Find MYBICARDHISTORY.csv
# mybicard_200721_200725.csv
# 67. Extracting 29_BIS_MYBI (29).zip ...
# Find MYBICARDHISTORY.csv
# mybicard_200930_201004.csv
# 68. Extracting 29_BIS_MYBI - 2021-02-09T174832.039.zip ...
# Find MYBICARDHISTORY.csv
# mybicard_200701_200705.csv
# 69. Extracting 29_BIS_MYBI - 2021-02-09T174833.074.zip ...
# Find MYBICARDHISTORY.csv
# mybicard_200630_200705.csv
# 70. Extracting 29_BIS_MYBI (1).zip ...
# Find MYBICARDHISTORY.csv
# mybicard_201106_201109.csv
# 71. Extracting 29_BIS_MYBI - 2021-02-09T174928.982.zip ...
# Find MYBICARDHISTORY.csv
# mybicard_200607_200613.csv
# 72. Extracting 29_BIS_MYBI - 2021-02-09T174957.612.zip ...
# File size 0
# 73. Extracting 29_BIS_MYBI (33).zip ...
# Find MYBICARDHISTORY.csv
# mybicard_200923_200927.csv
# 74. Extracting 29_BIS_MYBI (57).zip ...
# Find MYBICARDHISTORY.csv
# mybicard_200824_200828.csv
# 75. Extracting 29_BIS_MYBI (98).zip ...
# Find MYBICARDHISTORY.csv
# mybicard_200713_200716.csv
# 76. Extracting 29_BIS_MYBI (81).zip ...
# Find MYBICARDHISTORY.csv
# mybicard_200730_200804.csv
# 77. Extracting 29_BIS_MYBI - 2021-02-09T174857.474.zip ...
# Find MYBICARDHISTORY.csv
# mybicard_200622_200628.csv
# 78. Extracting 29_BIS_MYBI (63).zip ...
# Find MYBICARDHISTORY.csv
# mybicard_200818_200821.csv
# 79. Extracting 29_BIS_MYBI (93).zip ...
# Find MYBICARDHISTORY.csv
# mybicard_200718_200721.csv
# 80. Extracting TR051900200001 (2).zip ...
# Find MYBICARDHISTORY.csv
# mybicard_201127_201130.csv
# 81. Extracting 29_BIS_MYBI (24).zip ...
# Find MYBICARDHISTORY.csv
# mybicard_201002_201005.csv
# 82. Extracting 29_BIS_MYBI - 2021-02-09T175103.014.zip ...
# Find MYBICARDHISTORY.csv
# mybicard_200412_200416.csv
# 83. Extracting 29_BIS_MYBI (96).zip ...
# Find MYBICARDHISTORY.csv
# mybicard_200715_200719.csv
# 84. Extracting 29_BIS_MYBI (2).zip ...
# Find MYBICARDHISTORY.csv
# 85. Extracting 29_BIS_MYBI (51).zip ...
# Find MYBICARDHISTORY.csv
# mybicard_200901_200905.csv
# 86. Extracting 29_BIS_MYBI (10).zip ...
# Find MYBICARDHISTORY.csv
# mybicard_201012_201016.csv
# 87. Extracting TR051900200001 (4).zip ...
# Find MYBICARDHISTORY.csv
# mybicard_201125_201129.csv
# 88. Extracting 29_BIS_MYBI - 2021-02-09T174922.885.zip ...
# Find MYBICARDHISTORY.csv
# mybicard_200613_200616.csv
# 89. Extracting 29_BIS_MYBI (89).zip ...
# Find MYBICARDHISTORY.csv
# mybicard_200722_200726.csv
# 90. Extracting 29_BIS_MYBI (54).zip ...
# Find MYBICARDHISTORY.csv
# mybicard_200830_200902.csv
# 91. Extracting 29_BIS_MYBI - 2021-02-09T174859.651.zip ...
# Find MYBICARDHISTORY.csv
# mybicard_200620_200623.csv
# 92. Extracting 29_BIS_MYBI (94).zip ...
# Find MYBICARDHISTORY.csv
# mybicard_200717_200721.csv
# 93. Extracting 29_BIS_MYBI - 2021-02-09T174903.713.zip ...
# Find MYBICARDHISTORY.csv
# mybicard_200616_200621.csv
# 94. Extracting 29_BIS_MYBI (68).zip ...
# Find MYBICARDHISTORY.csv
# mybicard_200813_200818.csv
# 95. Extracting 29_BIS_MYBI (36).zip ...
# Find MYBICARDHISTORY.csv
# mybicard_200918_200922.csv
# 96. Extracting 29_BIS_MYBI - 2021-02-09T175014.801.zip ...
# Find MYBICARDHISTORY.csv
# mybicard_200526_200529.csv
# 97. Extracting 29_BIS_MYBI (53).zip ...
# Find MYBICARDHISTORY.csv
# mybicard_200831_200903.csv
# 98. Extracting 29_BIS_MYBI (41).zip ...
# Find MYBICARDHISTORY.csv
# mybicard_200911_200916.csv
# 99. Extracting 29_BIS_MYBI (37).zip ...
# Find MYBICARDHISTORY.csv
# mybicard_200915_200918.csv
# 100. Extracting 29_BIS_MYBI (69).zip ...
# Find MYBICARDHISTORY.csv
# mybicard_200808_200811.csv
# 101. Extracting 29_BIS_MYBI - 2021-02-09T174858.514.zip ...
# Find MYBICARDHISTORY.csv
# mybicard_200621_200626.csv
# 102. Extracting 29_BIS_MYBI (16).zip ...
# Find MYBICARDHISTORY.csv
# mybicard_201006_201010.csv
# 103. Extracting 29_BIS_MYBI - 2021-02-09T174955.490.zip ...
# File size 0
# 104. Extracting 29_BIS_MYBI - 2021-02-09T174956.497.zip ...
# File size 0
# 105. Extracting 29_BIS_MYBI (22).zip ...
# Find MYBICARDHISTORY.csv
# mybicard_200920_200923.csv
# 106. Extracting 29_BIS_MYBI (42).zip ...
# Find MYBICARDHISTORY.csv
# mybicard_200910_200914.csv
# 107. Extracting 29_BIS_MYBI - 2021-02-09T174951.296.zip ...
# Find MYBICARDHISTORY.csv
# mybicard_200603_200607.csv
# 108. Extracting 29_BIS_MYBI (86).zip ...
# Find MYBICARDHISTORY.csv
# mybicard_200725_200728.csv
# 109. Extracting 29_BIS_MYBI (78).zip ...
# Find MYBICARDHISTORY.csv
# mybicard_200802_200805.csv
# 110. Extracting 29_BIS_MYBI - 2021-02-09T175031.557.zip ...
# Find MYBICARDHISTORY.csv
# mybicard_200510_200513.csv
# 111. Extracting 29_BIS_MYBI - 2021-02-09T175047.816.zip ...
# Find MYBICARDHISTORY.csv
# 112. Extracting TR051900200001 (10).zip ...
# Find MYBICARDHISTORY.csv
# mybicard_201119_201123.csv
# 113. Extracting 29_BIS_MYBI (3).zip ...
# Find MYBICARDHISTORY.csv
# mybicard_201104_201108.csv
# 114. Extracting TR051900200001 (8).zip ...
# Find MYBICARDHISTORY.csv
# mybicard_201121_201124.csv
# 115. Extracting 29_BIS_MYBI - 2021-02-09T174925.865.zip ...
# Find MYBICARDHISTORY.csv
# mybicard_200610_200614.csv
# 116. Extracting TR051900200001 (11).zip ...
# Find MYBICARDHISTORY.csv
# mybicard_201118_201121.csv
# 118. Extracting 29_BIS_MYBI - 2021-02-09T175058.864.zip ...
# Find MYBICARDHISTORY.csv
# mybicard_200422_200427.csv
# 119. Extracting 29_BIS_MYBI - 2021-02-09T175050.996.zip ...
# Find MYBICARDHISTORY.csv
# mybicard_200425_200430.csv
# 120. Extracting 29_BIS_MYBI (46).zip ...
# Find MYBICARDHISTORY.csv
# mybicard_200906_200909.csv
# 121. Extracting 29_BIS_MYBI - 2021-02-09T175104.065.zip ...
# Find MYBICARDHISTORY.csv
# mybicard_200411_200414.csv
# 122. Extracting 29_BIS_MYBI (39).zip ...
# Find MYBICARDHISTORY.csv
# mybicard_200913_200917.csv
# 123. Extracting 29_BIS_MYBI - 2021-02-09T175024.257.zip ...
# Find MYBICARDHISTORY.csv
# mybicard_200519_200522.csv
# 124. Extracting 29_BIS_MYBI - 2021-02-09T175026.342.zip ...
# Find MYBICARDHISTORY.csv
# mybicard_200516_200519.csv
# 125. Extracting 29_BIS_MYBI - 2021-02-09T174831.051.zip ...
# Find MYBICARDHISTORY.csv
# mybicard_200702_200706.csv
# 126. Extracting 29_BIS_MYBI (47).zip ...
# Find MYBICARDHISTORY.csv
# mybicard_200905_200908.csv
# 127. Extracting 29_BIS_MYBI (72).zip ...
# Find MYBICARDHISTORY.csv
# mybicard_200803_200807.csv
# 128. Extracting 29_BIS_MYBI - 2021-02-09T174902.676.zip ...
# Find MYBICARDHISTORY.csv
# mybicard_200617_200621.csv
# 129. Extracting 29_BIS_MYBI (56).zip ...
# Find MYBICARDHISTORY.csv
# mybicard_200825_200828.csv
# 130. Extracting 29_BIS_MYBI (55).zip ...
# Find MYBICARDHISTORY.csv
# mybicard_200828_200901.csv
# 131. Extracting 29_BIS_MYBI - 2021-02-09T174900.651.zip ...
# Find MYBICARDHISTORY.csv
# mybicard_200619_200623.csv
# 132. Extracting 29_BIS_MYBI - 2021-02-09T174901.699.zip ...
# Find MYBICARDHISTORY.csv
# mybicard_200618_200623.csv
# 133. Extracting 29_BIS_MYBI (100).zip ...
# Find MYBICARDHISTORY.csv
# mybicard_200711_200715.csv
# 134. Extracting 29_BIS_MYBI (71).zip ...
# Find MYBICARDHISTORY.csv
# mybicard_200810_200813.csv
# 135. Extracting TR051900200001 (12).zip ...
# Find MYBICARDHISTORY.csv
# mybicard_201117_201120.csv
# 136. Extracting 29_BIS_MYBI - 2021-02-09T175106.276.zip ...
# Find MYBICARDHISTORY.csv
# mybicard_200409_200413.csv
# 137. Extracting 29_BIS_MYBI - 2021-02-09T175049.935.zip ...
# Find MYBICARDHISTORY.csv
# mybicard_200426_200430.csv
# 138. Extracting 29_BIS_MYBI - 2021-02-09T175121.012.zip ...
# Find MYBICARDHISTORY.csv
# mybicard_200407_200410.csv
# 139. Extracting 29_BIS_MYBI - 2021-02-09T174958.607.zip ...
# File size 0
# 140. Extracting 29_BIS_MYBI (97).zip ...
# Find MYBICARDHISTORY.csv
# mybicard_200714_200718.csv
# 141. Extracting 29_BIS_MYBI (62).zip ...
# Find MYBICARDHISTORY.csv
# mybicard_200819_200823.csv
# 142. Extracting 29_BIS_MYBI (38).zip ...
# Find MYBICARDHISTORY.csv
# mybicard_200914_200917.csv
# 143. Extracting 29_BIS_MYBI (21).zip ...
# Find MYBICARDHISTORY.csv
# mybicard_200925_200929.csv
# 144. Extracting 29_BIS_MYBI (17).zip ...
# Find MYBICARDHISTORY.csv
# mybicard_201003_201005.csv
# 145. Extracting 29_BIS_MYBI - 2021-02-09T175045.775.zip ...
# Find MYBICARDHISTORY.csv
# mybicard_200501_200505.csv
# 146. Extracting 29_BIS_MYBI - 2021-02-09T175025.276.zip ...
# Find MYBICARDHISTORY.csv
# mybicard_200518_200521.csv
# 147. Extracting 29_BIS_MYBI (25).zip ...
# Find MYBICARDHISTORY.csv
# mybicard_200929_201004.csv
# 148. Extracting 29_BIS_MYBI - 2021-02-09T174828.912.zip ...
# Find MYBICARDHISTORY.csv
# mybicard_200704_200710.csv
# 149. Extracting 29_BIS_MYBI - 2021-02-09T174835.125.zip ...
# Find MYBICARDHISTORY.csv
# mybicard_200628_200701.csv
# 150. Extracting 29_BIS_MYBI - 2021-02-09T175029.457.zip ...
# Find MYBICARDHISTORY.csv
# mybicard_200512_200515.csv
# 151. Extracting 29_BIS_MYBI - 2021-02-09T175011.668.zip ...
# Find MYBICARDHISTORY.csv
# mybicard_200528_200602.csv
# 152. Extracting 29_BIS_MYBI - 2021-02-09T174924.818.zip ...
# Find MYBICARDHISTORY.csv
# mybicard_200611_200615.csv
# 153. Extracting 29_BIS_MYBI - 2021-02-09T174855.390.zip ...
# Find MYBICARDHISTORY.csv
# mybicard_200624_200629.csv
# 154. Extracting 29_BIS_MYBI - 2021-02-09T175119.959.zip ...
# Find MYBICARDHISTORY.csv
# mybicard_200408_200412.csv
# 155. Extracting 29_BIS_MYBI - 2021-02-09T174949.261.zip ...
# Find MYBICARDHISTORY.csv
# mybicard_200605_200610.csv
# 156. Extracting 29_BIS_MYBI - 2021-02-09T175013.780.zip ...
# Find MYBICARDHISTORY.csv
# mybicard_200531_200605.csv
# 157. Extracting 29_BIS_MYBI (13).zip ...
# Find MYBICARDHISTORY.csv
# mybicard_201009_201013.csv
# 158. Extracting 29_BIS_MYBI - 2021-02-09T175008.607.zip ...
# File size 0
# 159. Extracting 29_BIS_MYBI - 2021-02-09T175048.935.zip ...
# Find MYBICARDHISTORY.csv
# mybicard_200427_200501.csv
# 160. Extracting 29_BIS_MYBI (99).zip ...
# Find MYBICARDHISTORY.csv
# mybicard_200712_200715.csv
# 161. Extracting 29_BIS_MYBI (32).zip ...
# Find MYBICARDHISTORY.csv
# mybicard_200924_200928.csv
# 162. Extracting 29_BIS_MYBI (8).zip ...
# Find MYBICARDHISTORY.csv
# mybicard_201028_201102.csv
# 163. Extracting 29_BIS_MYBI (19).zip ...
# Find MYBICARDHISTORY.csv
# mybicard_200916_200920.csv
# 164. Extracting 29_BIS_MYBI - 2021-02-09T175101.983.zip ...
# Find MYBICARDHISTORY.csv
# mybicard_200413_200417.csv
# 165. Extracting 29_BIS_MYBI (80).zip ...
# Find MYBICARDHISTORY.csv
# mybicard_200731_200804.csv
# 166. Extracting 29_BIS_MYBI - 2021-02-09T174953.382.zip ...
# Find MYBICARDHISTORY.csv
# mybicard_200601_200605.csv
# 167. Extracting 29_BIS_MYBI (58).zip ...
# Find MYBICARDHISTORY.csv
# mybicard_200823_200827.csv
# 168. Extracting 29_BIS_MYBI - 2021-02-09T175009.583.zip ...
# File size 0
# 169. Extracting TR051900200001 (13).zip ...
# Find MYBICARDHISTORY.csv
# mybicard_201116_201119.csv
# 170. Extracting 29_BIS_MYBI - 2021-02-09T174930.013.zip ...
# Find MYBICARDHISTORY.csv
# mybicard_200606_200610.csv
# 171. Extracting 29_BIS_MYBI - 2021-02-09T174952.412.zip ...
# Find MYBICARDHISTORY.csv
# mybicard_200602_200605.csv
# 172. Extracting 29_BIS_MYBI - 2021-02-09T174854.341.zip ...
# Find MYBICARDHISTORY.csv
# mybicard_200625_200629.csv
# 173. Extracting 29_BIS_MYBI - 2021-02-09T175101.003.zip ...
# Find MYBICARDHISTORY.csv
# mybicard_200419_200422.csv
# 174. Extracting 29_BIS_MYBI (44).zip ...
# Find MYBICARDHISTORY.csv
# mybicard_200908_200911.csv
# 175. Extracting 29_BIS_MYBI (91).zip ...
# Find MYBICARDHISTORY.csv
# mybicard_200720_200723.csv
# 176. Extracting 29_BIS_MYBI - 2021-02-09T174834.093.zip ...
# Find MYBICARDHISTORY.csv
# mybicard_200629_200705.csv
# 177. Extracting 29_BIS_MYBI (48).zip ...
# Find MYBICARDHISTORY.csv
# mybicard_200904_200907.csv
# 178. Extracting 29_BIS_MYBI (40).zip ...
# Find MYBICARDHISTORY.csv
# mybicard_200912_200915.csv
# 179. Extracting 29_BIS_MYBI - 2021-02-09T175057.869.zip ...
# Find MYBICARDHISTORY.csv
# mybicard_200423_200428.csv
# 180. Extracting 29_BIS_MYBI - 2021-02-09T175059.904.zip ...
# Find MYBICARDHISTORY.csv
# mybicard_200420_200423.csv
# 181. Extracting 29_BIS_MYBI (67).zip ...
# Find MYBICARDHISTORY.csv
# mybicard_200814_200818.csv
# 182. Extracting TR051900200001 (5).zip ...
# Find MYBICARDHISTORY.csv
# mybicard_201124_201127.csv
# 183. Extracting 29_BIS_MYBI (11).zip ...
# Find MYBICARDHISTORY.csv
# mybicard_201011_201014.csv
# 184. Extracting 29_BIS_MYBI (4).zip ...
# Find MYBICARDHISTORY.csv
# mybicard_201103_201106.csv
# 185. Extracting 29_BIS_MYBI - 2021-02-09T175010.600.zip ...
# File size 0
# 186. Extracting 29_BIS_MYBI - 2021-02-09T175033.610.zip ...
# Find MYBICARDHISTORY.csv
# mybicard_200508_200512.csv
# 187. Extracting TR051900200001 (3).zip ...
# Find MYBICARDHISTORY.csv
# mybicard_201126_201130.csv
# 188. Extracting 29_BIS_MYBI (83).zip ...
# Find MYBICARDHISTORY.csv
# mybicard_200728_200731.csv
# 189. Extracting 29_BIS_MYBI (70).zip ...
# Find MYBICARDHISTORY.csv
# mybicard_200804_200808.csv
# 190. Extracting 29_BIS_MYBI - 2021-02-09T174923.778.zip ...
# Find MYBICARDHISTORY.csv
# mybicard_200612_200615.csv
# 191. Extracting 29_BIS_MYBI (75).zip ...
# Find MYBICARDHISTORY.csv
# mybicard_200812_200816.csv
# 192. Extracting TR051900200001 (1).zip ...
# Find MYBICARDHISTORY.csv
# mybicard_201128_201202.csv
# 193. Extracting 29_BIS_MYBI (66).zip ...
# Find MYBICARDHISTORY.csv
# mybicard_200815_200819.csv
# 194. Extracting 29_BIS_MYBI - 2021-02-09T174810.586.zip ...
# Find MYBICARDHISTORY.csv
# mybicard_200709_200713.csv
# 195. Extracting 29_BIS_MYBI - 2021-02-09T175017.935.zip ...
# Find MYBICARDHISTORY.csv
# mybicard_200521_200525.csv
# 196. Extracting 29_BIS_MYBI (43).zip ...
# Find MYBICARDHISTORY.csv
# mybicard_200909_200913.csv
# 197. Extracting 29_BIS_MYBI (50).zip ...
# Find MYBICARDHISTORY.csv
# mybicard_200902_200907.csv
# 198. Extracting 29_BIS_MYBI (30).zip ...
# Find MYBICARDHISTORY.csv
# mybicard_201004_201005.csv
# 199. Extracting 29_BIS_MYBI (76).zip ...
# Find MYBICARDHISTORY.csv
# mybicard_200806_200810.csv
# 200. Extracting 29_BIS_MYBI - 2021-02-09T174927.944.zip ...
# Find MYBICARDHISTORY.csv
# mybicard_200608_200613.csv
# 201. Extracting 29_BIS_MYBI (87).zip ...
# Find MYBICARDHISTORY.csv
# mybicard_200724_200728.csv
# 202. Extracting 29_BIS_MYBI - 2021-02-09T175044.717.zip ...
# Find MYBICARDHISTORY.csv
# mybicard_200502_200505.csv

# %% [markdown]
# #### CSV 파일 하나로 합치기

# %%
mybi_csv_gen = (pd.read_csv(f"{unzip_data_loc}/{x}", dtype = {"route_nm" : str}) for x in os.listdir(unzip_data_loc) if os.path.splitext(x)[1] == ".csv")

# %%
# %%time
mybicard = pd.concat(mybi_csv_gen)
# Out:
# CPU times: user 43.1 s, sys: 3.54 s, total: 46.6 s
# Wall time: 46.6 s

# %%
import pyarrow.feather as feather

# %%
# %%time
with open('mybicard.ftr', 'wb') as f:
    feather.write_feather(mybicard, f)
# Out:
# CPU times: user 12.6 s, sys: 2.41 s, total: 15 s
# Wall time: 10.6 s

# %%
mybicard.shape
# Out:
# (37479749, 15)

# %%
mybicard = mybicard.drop_duplicates()
