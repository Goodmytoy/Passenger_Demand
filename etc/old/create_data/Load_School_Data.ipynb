# %%
from utils.School_Data_by_API import *

# %%
serviceKey = "eLWdQyzctRdtv8bEOuewsTtK6sNkoWp1bE74OUBk43jg4tU6AsI6yYt6Z%2B7sOeaqtB5pTH2yHuPRIuEHtu5amQ%3D%3D"

# %%
params_dict= {"serviceKey" : serviceKey,
              "pageNo" : 1,
              "numOfRows" : 1000,
              "type" : "xml"}

# %%
school_api = School_Data_by_API(params_dict = params_dict)

# %%
# %%time
school_data = school_api.get()
# Out:
# n_rows : 1000, total_count : 500, max_page = 1
# CPU times: user 98.6 ms, sys: 0 ns, total: 98.6 ms
# Wall time: 5.67 s

# %%
school_data.head()
# Out:
#      schoolId   schoolNm schoolSe    fondDate fondType bnhhSe operSttus  \
# 0  B000013333  진주외국어고등학교     고등학교  1970-12-26       사립     본교        운영
# 1  B000022925     용남고등학교     고등학교  1991-03-09       공립     본교        운영
# 2  B000010931      장곡중학교      중학교  2001-03-06       공립     본교        운영
# 3  B000011284      대정중학교      중학교  1946-11-08       공립     본교        운영
# 4  B000008177      안천중학교      중학교  1991-03-01       공립     본교        운영
#
#                      lnmadr                   rdnmadr cddcCode      cddcNm  \
# 0     경상남도 진주시 일반성면 개암리 884  경상남도 진주시 일반성면 동부로 2014-6  9010000     경상남도교육청
# 1    충청남도 계룡시 신도안면 남선리 1278    충청남도 계룡시 신도안면 신도안1길 32  8140000     충청남도교육청
# 2       경상북도 칠곡군 석적읍 중리 246     경상북도 칠곡군 석적읍 남중리8길 13  8750000     경상북도교육청
# 3  제주특별자치도 서귀포시 대정읍 하모리 778  제주특별자치도 서귀포시 대정읍 비행장로 18  9290000  제주특별자치도교육청
# 4        서울특별시 금천구 독산동 1089       서울특별시 금천구 한내로 69-44  7010000    서울특별시교육청
#
#   edcSport        edcSportNm   creatDate  changeDate       latitude  \
# 0  9051000       경상남도진주교육지원청  2013-11-29  2020-09-22  35.1696561814
# 1  8222000     충청남도논산계룡교육지원청  2013-11-29  2020-09-22  36.2943092118
# 2  8941000       경상북도칠곡교육지원청  2013-11-29  2020-09-22  36.0734554758
# 3  9299000  제주특별자치도서귀포시교육지원청  2013-11-29  2020-09-22  33.2199616211
# 4  7041000      서울특별시남부교육지원청  2013-11-29  2020-09-22  37.4595242629
#
#         longitude referenceDate insttCode
# 0  128.2816679523    2021-03-25   7001220
# 1  127.2447646202    2021-03-25   7001220
# 2     128.4150883    2021-03-25   7001220
# 3  126.2532326652    2021-03-25   7001220
# 4  126.8874987711    2021-03-25   7001220

# %%
school_data.to_csv("/home/seho/Passenger_Demand/data/school_data.csv")
